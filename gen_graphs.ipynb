# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from funky import extractor

# %%
df_gc = extractor('gc')
df_nsc = extractor('nsc')
df_ysc = extractor('ysc')

# %%
plt.hist(df_nsc['S1'], 'auto')
plt.yscale('log')
plt.show()

# %%
plt.hist(df_nsc['Mrem'], 'auto')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
plt.hist(df_nsc['S2'], 'auto')
plt.yscale('log')
plt.show()

# %%
plt.scatter(df_nsc['t_pair'], df_nsc['t_elapsed'])
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
selected_feat = ['M1', 'M2', 'S1', 'S2', 't_pair', 't_elapsed','kick','Mrem', 'Srem', 'esca_v', 'Mcluster', 'Z']

for feat in selected_feat:# un plot per selected
    plt.xscale('log') 
    plt.scatter(df_nsc[feat], df_nsc['gen'],marker='.')
    plt.title(feat)
    plt.show()

# %%
selected_feat = ['t_elapsed', 'esca_v', 'Mcluster']

for feat in selected_feat:# un plot per selected
    plt.xscale('log') 
    plt.scatter(df_gc[feat], df_gc['gen'],marker='.')
    plt.title(feat)
    plt.show()

# %%
plt.scatter(df_nsc['Mcluster'], df_nsc['esca_v'])
plt.xscale('log')
plt.show()
