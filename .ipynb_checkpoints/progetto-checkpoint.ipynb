# %% [raw]
# TODO:
# - Marghe: capire cosa è il random forest
# - Gigi: estendere l'algoritmo qui sotto a tutti i cluster e metallicità
# - Giovi : continua a fare i plot
# - Gabri : capire cosa è il random forest

# %% [markdown]
# # Remember the Dyn dylemma

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

cols = [0, 1, 2, 3, 4, 9, 13, 15, 16, 17, 25, 27]
heade = ['ID', '$M_1$', '$M_2$', '$S_1$', '$S_2$', '$t_{pair}$', '$t_{elapsed}$',
         '$M_{rem}$', '$S_{rem}$', '$v_{escape}$', '$M_{tot}$', 'Gen']
dyn = '/Dyn'  # Change this to whatever your dyn opinion is



def extractor(path_data, cluster):
    metal = {}
    wichcluster = os.listdir(path_data)
    if cluster == 'gc': cluster = wichcluster[2]
    if cluster == 'nsc': cluster = wichcluster[1]
    if cluster == 'ysc': cluster = wichcluster[0]
    for i in os.listdir(path_data + cluster + dyn):
        name = path_data + cluster + dyn + '/' + str(i) + '/nth_generation.txt'
        metal[str(i)] = pd.read_csv(name, delimiter=' ', skiprows=1, usecols=cols, names=heade)
    whole = pd.concat(metal.values())
    return metal, whole

# %%
df_gc, whole_gc = extractor('data/','gc')  # globular clusters
df_nsc, whole_nsc = extractor('data/','nsc')  # nuclear clusters
df_ysc, whole_ysc = extractor('data/','ysc')  # young star clusters

# %% [markdown]
# # Grafici

# %% [markdown]
# ## GC

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,10))
ax[0,0].hist(whole_gc['$M_1$'], 'auto')
ax[0,0].set_title('Mass of Primary BH')
ax[0,0].set_xlim(0,250)  # There are way larger values, but they aren't visible

ax[0,1].hist(whole_gc['$M_2$'] / whole_gc['$M_1$'], 'auto')
ax[0,1].set_title('Mass ratio')

ax[1,0].hist(whole_gc['Gen'], whole_gc['Gen'].nunique())
ax[1,0].set_title('Generations')
ax[1,0].set_ylim(0, 2e5)

ax[1,1].scatter(whole_gc['$M_1$'], whole_gc['$M_2$'], marker='.')  # Of course the limit will be a y=x line, since y can't
# exceed x

plt.show()

# %% [markdown]
# ## YSC

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,10))
ax[0,0].hist(whole_ysc['$M_1$'], 'auto')
ax[0,0].set_title('Mass of Primary BH')
ax[0,0].set_xlim(0,250)  # There are way larger values, but they aren't visible

ax[0,1].hist(whole_ysc['$M_2$'] / whole_ysc['$M_1$'], 'auto')
ax[0,1].set_title('Mass ratio')

ax[1,0].hist(whole_ysc['Gen'], whole_ysc['Gen'].nunique())
ax[1,0].set_title('Generations')
ax[1,0].set_ylim(0, 2e5)


plt.show()

# %% [markdown]
# ## NSC

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,10))
ax[0,0].hist(whole_nsc['$M_1$'], 'auto')
ax[0,0].set_title('Mass of Primary BH')

ax[0,1].hist(whole_nsc['$M_2$'] / whole_nsc['$M_1$'], 'auto')
ax[0,1].set_title('Mass ratio')

ax[1,0].hist(whole_nsc['Gen'], whole_nsc['Gen'].nunique())
ax[1,0].set_title('Generations')



plt.show()
